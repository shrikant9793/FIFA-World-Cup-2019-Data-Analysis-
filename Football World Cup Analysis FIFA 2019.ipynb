# %% [markdown]
# # FIFA 19 FootBall World Cup Data Visualization

# %%
#import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import os
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')

# %%
# %time
data = pd.read_csv(r"C:\Users\hp\Desktop\New folder\Python Object and Data Structure Basics\csv file\All Files\FIFA_Football.csv")
data.head()
# Out:
# Wall time: 0 ns
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# 3    Manchester United  ...      68.0    15.0           21.0           13.0
# 4      Manchester City  ...      88.0    68.0           58.0           51.0
#
#   GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0      6.0        11.0       15.0           14.0        8.0        €226.5M
# 1      7.0        11.0       15.0           14.0       11.0        €127.1M
# 2      9.0         9.0       15.0           15.0       11.0        €228.1M
# 3     90.0        85.0       87.0           88.0       94.0        €138.6M
# 4     15.0        13.0        5.0           10.0       13.0        €196.4M
#
# [5 rows x 89 columns]

# %%
data.shape
# Out:
# (18207, 89)

# %%
data.size
# Out:
# 1620423

# %%
def country(x):
    return data[data['Nationality']== x][['Name', 'Overall', 'Potential', 'Position']]

country('India')
# Out:
#                   Name  Overall  Potential Position
# 8605        S. Chhetri       67         67       LS
# 10011       S. Jhingan       65         71      RCB
# 12598    J. Lalpekhlua       63         64       RS
# 12811  G. Singh Sandhu       63         68       GK
# 13508    A. Edathodika       62         62      LCB
# 14054        P. Halder       61         67      RCM
# 14199         P. Kotal       61         66       RB
# 14218         L. Ralte       61         62       LW
# 14705           N. Das       60         65       LB
# 14786         U. Singh       60         67       RM
# 14915       H. Narzary       60         66       LM
# 15356         R. Singh       59         59       ST
# 15643         S. Singh       59         65       CB
# 15652         A. Thapa       59         71      LCM
# 15855       M. Rafique       58         61       CM
# 15864         A. Singh       58         62       GK
# 15884         B. Singh       58         58       ST
# 16135          S. Bose       58         66       LB
# 16265        R. Borges       58         60      CDM
# 16450          S. Paul       57         57      NaN
# 16499        A. Mondal       57         57       CB
# 16539  L. Lalruatthara       57         63      NaN
# 16793       E. Lyngdoh       56         56      NaN
# 16903   J. Lalrinzuala       56         64       LB
# 16976     A. Kuruniyan       56         70       LW
# 17129         J. Singh       55         58      NaN
# 17197         V. Kaith       55         64       GK
# 17339         S. Passi       54         63      NaN
# 17436   D. Lalhlimpuia       54         67      NaN
# 17539         C. Singh       53         62      NaN

# %%
country('Germany')
# Out:
#                 Name  Overall  Potential Position
# 11          T. Kroos       90         90      LCM
# 18     M. ter Stegen       89         92       GK
# 22          M. Neuer       89         89       GK
# 34        M. Hummels       88         88      LCB
# 55           L. Sané       86         92       LW
# ...              ...      ...        ...      ...
# 18101      J. Hipper       50         59       GK
# 18127     N. Stephan       49         67       GK
# 18145     M. Harsman       49         65       GK
# 18187      C. Ehlich       47         59       RB
# 18189     A. Kaltner       47         61       ST
#
# [1198 rows x 4 columns]

# %%
country('England')
# Out:
#                  Name  Overall  Potential Position
# 16            H. Kane       89         91       ST
# 60        R. Sterling       86         89       RW
# 117           D. Alli       84         90      LCM
# 135         K. Walker       84         84       RB
# 180       J. Pickford       83         88       GK
# ...               ...      ...        ...      ...
# 18198      J. Livesey       47         70       GK
# 18202    J. Lundstram       47         65       CM
# 18204       B. Worman       47         67       ST
# 18205  D. Walker-Rice       47         66       RW
# 18206       G. Nugent       46         66       CM
#
# [1662 rows x 4 columns]

# %%
country('Spain')
# Out:
#                       Name  Overall  Potential Position
# 3                   De Gea       91         93       GK
# 8             Sergio Ramos       91         91      RCB
# 13             David Silva       90         90      LCM
# 20         Sergio Busquets       89         89      CDM
# 30                    Isco       88         91       LW
# ...                    ...      ...        ...      ...
# 17043        Cristian Arco       55         61       GK
# 17070               Taliby       55         64       GK
# 17116         Víctor Gómez       55         73       LB
# 17274            Hugo Díaz       55         70       CB
# 17926  Carlos Mendes Gomes       51         61      CAM
#
# [1072 rows x 4 columns]

# %%
country('Argentina')
# Out:
#                  Name  Overall  Potential Position
# 0            L. Messi       94         94       RF
# 15          P. Dybala       89         94       LF
# 23          S. Agüero       89         89       ST
# 38         G. Higuaín       88         88       LS
# 43          M. Icardi       87         90       ST
# ...               ...      ...        ...      ...
# 17349        T. Durso       54         74       GK
# 17355      V. Barbero       54         73       ST
# 17638      E. Alarcón       53         57       GK
# 17861   F. Bustamante       52         66       RM
# 17987  L. Finochietto       51         59       GK
#
# [937 rows x 4 columns]

# %%
#findout clubwise goals
def club(x):
    return data[data['Club'] == x][['Name', 'Position', 'Overall', 'Nationality', 'Age', 'Wage', 'Value', 'Contract Valid Until']]

club('FC Barcelona')
# Out:
#                   Name Position  Overall  Nationality  Age   Wage    Value  \
# 0             L. Messi       RF       94    Argentina   31  €565K  €110.5M
# 7            L. Suárez       RS       91      Uruguay   31  €455K     €80M
# 18       M. ter Stegen       GK       89      Germany   26  €240K     €58M
# 20     Sergio Busquets      CDM       89        Spain   29  €315K   €51.5M
# 32            Coutinho       LW       88       Brazil   26  €340K   €69.5M
# 42           S. Umtiti       CB       87       France   24  €205K     €57M
# 49          Jordi Alba       LB       87        Spain   29  €250K     €38M
# 53          I. Rakitić      RCM       87      Croatia   30  €260K   €46.5M
# 54               Piqué      RCB       87        Spain   31  €240K     €34M
# 96            A. Vidal      CAM       85        Chile   31  €205K     €26M
# 155         O. Dembélé       RW       83       France   21  €155K     €40M
# 192      Sergi Roberto       RB       83        Spain   26  €170K   €26.5M
# 228             Arthur      LCM       82       Brazil   21  €125K   €32.5M
# 236             Malcom       RW       82       Brazil   21  €140K   €31.5M
# 239         C. Lenglet      LCB       82       France   23  €135K     €26M
# 263            Rafinha      CAM       82       Brazil   25  €165K   €29.5M
# 266       J. Cillessen       GK       82  Netherlands   29  €135K     €18M
# 324      Nélson Semedo       RB       81     Portugal   24  €125K     €20M
# 613       Denis Suárez       CM       79        Spain   24  €120K   €17.5M
# 1007             Munir       ST       77        Spain   22  €115K   €12.5M
# 1037      T. Vermaelen       CB       77      Belgium   32  €110K      €5M
# 3118      Sergi Samper      CDM       73        Spain   23   €69K    €4.8M
# 3684             Aleñá       CM       72        Spain   20   €58K      €6M
# 6000          M. Wagué       RB       69      Senegal   19   €20K    €1.6M
# 6102        Riqui Puig       CM       69        Spain   18   €24K    €2.1M
# 8284    Oriol Busquets      CDM       67        Spain   19   €14K    €1.5M
# 8289         Abel Ruiz       ST       67        Spain   18   €21K    €1.6M
# 8857           Miranda       LB       66        Spain   18   €12K    €1.2M
# 10526            Chumi       CB       65        Spain   19   €11K      €1M
# 10777     Jorge Cuenca       CB       65        Spain   18   €11K    €850K
# 11300    Guillem Jaime       RW       64        Spain   19   €13K    €975K
# 12502          Ezkieta       GK       63        Spain   21   €10K    €525K
# 14286       Iñaki Peña       GK       61        Spain   19    €4K    €450K
#
#       Contract Valid Until
# 0                     2021
# 7                     2021
# 18                    2022
# 20                    2023
# 32                    2023
# 42                    2023
# 49                    2020
# 53                    2021
# 54                    2022
# 96                    2021
# 155                   2022
# 192                   2022
# 228                   2024
# 236                   2023
# 239                   2023
# 263                   2020
# 266                   2021
# 324                   2022
# 613                   2020
# 1007                  2019
# 1037                  2019
# 3118                  2020
# 3684                  2022
# 6000                  2023
# 6102                  2021
# 8284                  2021
# 8289                  2021
# 8857                  2021
# 10526                 2020
# 10777                 2019
# 11300                 2020
# 12502                 2019
# 14286                 2021

# %%
club('Manchester City')
# Out:
#                      Name Position  Overall  Nationality  Age   Wage   Value  \
# 4            K. De Bruyne      RCM       91      Belgium   27  €355K   €102M
# 13            David Silva      LCM       90        Spain   32  €285K    €60M
# 23              S. Agüero       ST       89    Argentina   30  €300K  €64.5M
# 55                L. Sané       LW       86      Germany   22  €195K    €61M
# 56         Bernardo Silva       RW       86     Portugal   23  €180K  €59.5M
# 57                Ederson       GK       86       Brazil   24  €125K  €41.5M
# 60            R. Sterling       RW       86      England   23  €195K  €56.5M
# 75            Fernandinho      CDM       86       Brazil   33  €185K    €18M
# 84              R. Mahrez       RW       85      Algeria   27  €205K  €40.5M
# 89            N. Otamendi       CB       85    Argentina   30  €170K  €28.5M
# 107            V. Kompany       CB       85      Belgium   32  €170K    €22M
# 113            A. Laporte      LCB       84       France   24  €135K    €34M
# 135             K. Walker       RB       84      England   28  €165K  €24.5M
# 136           I. Gündoğan       CM       84      Germany   27  €175K    €32M
# 156         Gabriel Jesus       ST       83       Brazil   21  €130K    €41M
# 182             J. Stones      RCB       83      England   24  €125K  €28.5M
# 352              B. Mendy       LB       81       France   23  €105K    €20M
# 514              F. Delph       LB       80      England   28  €120K  €11.5M
# 645                Danilo       RB       79       Brazil   26  €110K    €12M
# 871              C. Bravo       GK       78        Chile   35   €50K   €2.4M
# 1304           E. Mangala       CB       76       France   27   €84K   €7.5M
# 2903             P. Foden      CAM       73      England   18   €36K     €8M
# 4652         O. Zinchenko       LB       71      Ukraine   21   €38K   €3.3M
# 6316           P. Sandler       CB       69  Netherlands   21   €28K   €1.7M
# 6559          Brahim Díaz       LW       69        Spain   18   €24K   €2.2M
# 8966             C. Gomes      CDM       66       France   17   €10K   €1.1M
# 13211         Eric García       CB       62        Spain   17    €6K   €550K
# 13814  C. Humphreys-Grant       CB       62      England   19    €6K   €600K
# 14197           L. Bolton       RM       61      England   18    €7K   €525K
# 14511            A. Muric       GK       61   Montenegro   19    €3K   €450K
# 15210            B. Garré       LW       60    Argentina   17    €7K   €400K
# 16403     T. Dele-Bashiru       CM       57      England   18    €6K   €210K
# 17451         D. Grimshaw       GK       54      England   20    €6K   €120K
#
#       Contract Valid Until
# 4                     2023
# 13                    2020
# 23                    2021
# 55                    2021
# 56                    2022
# 57                    2025
# 60                    2023
# 75                    2020
# 84                    2023
# 89                    2022
# 107                   2019
# 113                   2023
# 135                   2022
# 136                   2020
# 156                   2023
# 182                   2022
# 352                   2022
# 514                   2020
# 645                   2022
# 871                   2020
# 1304                  2019
# 2903                  2024
# 4652                  2021
# 6316                  2022
# 6559                  2019
# 8966                  2023
# 13211                 2022
# 13814                 2023
# 14197                 2020
# 14511                 2020
# 15210                 2020
# 16403                 2019
# 17451                 2021

# %%
club('Manchester United')
# Out:
#                   Name Position  Overall  Nationality  Age   Wage   Value  \
# 3               De Gea       GK       91        Spain   27  €260K    €72M
# 45            P. Pogba      RDM       87       France   25  €210K    €64M
# 47           R. Lukaku       ST       87      Belgium   25  €230K  €62.5M
# 93          A. Sánchez       RW       85        Chile   29  €215K  €37.5M
# 116         A. Martial       LW       84       France   22  €165K  €42.5M
# 132           N. Matić      CDM       84       Serbia   29  €165K    €24M
# 211          Juan Mata       RM       83        Spain   30  €160K  €24.5M
# 250               Fred       CM       82       Brazil   25  €140K  €26.5M
# 254         J. Lingard      CAM       82      England   25  €140K  €26.5M
# 319        M. Rashford       LW       81      England   20  €110K    €27M
# 327          E. Bailly       CB       81  Ivory Coast   24  €105K    €21M
# 374      Ander Herrera       CM       81        Spain   28  €140K  €17.5M
# 377        C. Smalling      RCB       81      England   28  €130K    €16M
# 399        A. Valencia       RM       81      Ecuador   32  €120K    €10M
# 454            L. Shaw       LB       80      England   22   €96K  €16.5M
# 526          S. Romero       GK       80    Argentina   31   €91K     €9M
# 584        V. Lindelöf       CB       79       Sweden   23   €91K  €14.5M
# 629            M. Rojo       CB       79    Argentina   28  €115K    €10M
# 654           P. Jones       CB       79      England   26  €110K    €12M
# 700        M. Fellaini       CM       79      Belgium   30  €120K  €11.5M
# 717           A. Young       LB       79      England   32  €110K     €7M
# 807    Andreas Pereira       CM       78       Brazil   22   €91K    €14M
# 1313        M. Darmian       LB       76        Italy   28   €88K     €6M
# 2561          L. Grant       GK       74      England   35   €39K   €1.3M
# 3451       Diogo Dalot       RB       72     Portugal   19   €26K   €4.7M
# 4513      S. McTominay       CM       71     Scotland   21   €43K   €3.8M
# 8191          A. Gomes      CAM       67      England   17   €15K   €1.5M
# 10087         T. Chong       RW       65  Netherlands   18   €13K   €1.1M
# 10457      E. Hamilton       CM       65     Scotland   19   €11K     €1M
# 10461       C. Gribbin      CAM       65      England   19   €11K   €1.2M
# 11081         R. Poole       CB       64        Wales   20   €13K   €675K
# 11422      R. Williams       CB       64      England   19    €8K   €875K
# 12545         J. Bohui       ST       63      England   19   €10K   €700K
#
#       Contract Valid Until
# 3                     2020
# 45                    2021
# 47                    2022
# 93                    2022
# 116                   2019
# 132                   2020
# 211                   2019
# 250                   2023
# 254                   2021
# 319                   2020
# 327                   2020
# 374                   2019
# 377                   2019
# 399                   2019
# 454                   2023
# 526                   2021
# 584                   2021
# 629                   2021
# 654                   2019
# 700                   2020
# 717                   2019
# 807                   2019
# 1313                  2019
# 2561                  2020
# 3451                  2023
# 4513                  2021
# 8191                  2021
# 10087                 2019
# 10457                 2020
# 10461                 2019
# 11081                 2019
# 11422                 2019
# 12545                 2019

# %%
data.Nationality.value_counts().sort_index(ascending=True).head(5)
# Out:
# Afghanistan     4
# Albania        40
# Algeria        60
# Andorra         1
# Angola         15
# Name: Nationality, dtype: int64

# %%
x = club('Machester City')

# %%
x.shape
# Out:
# (0, 8)

# %%
x = club('FC Barcelona')
x.shape
# Out:
# (33, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
#  13  Special                   18207 non-null  int64
#  14  Preferred Foot            18159 non-null  object
#  15  International Reputation  18159 non-null  float64
#  16  Weak Foot                 18159 non-null  float64
#  17  Skill Moves               18159 non-null  float64
#  18  Work Rate                 18159 non-null  object
#  19  Body Type                 18159 non-null  object
#  20  Real Face                 18159 non-null  object
#  21  Position                  18147 non-null  object
#  22  Jersey Number             18147 non-null  float64
#  23  Joined                    16654 non-null  object
#  24  Loaned From               1264 non-null   object
#  25  Contract Valid Until      17918 non-null  object
#  26  Height                    18159 non-null  object
#  27  Weight                    18159 non-null  object
#  28  LS                        16122 non-null  object
#  29  ST                        16122 non-null  object
#  30  RS                        16122 non-null  object
#  31  LW                        16122 non-null  object
#  32  LF                        16122 non-null  object
#  33  CF                        16122 non-null  object
#  34  RF                        16122 non-null  object
#  35  RW                        16122 non-null  object
#  36  LAM                       16122 non-null  object
#  37  CAM                       16122 non-null  object
#  38  RAM                       16122 non-null  object
#  39  LM                        16122 non-null  object
#  40  LCM                       16122 non-null  object
#  41  CM                        16122 non-null  object
#  42  RCM                       16122 non-null  object
#  43  RM                        16122 non-null  object
#  44  LWB                       16122 non-null  object
#  45  LDM                       16122 non-null  object
#  46  CDM                       16122 non-null  object
#  47  RDM                       16122 non-null  object
#  48  RWB                       16122 non-null  object
#  49  LB                        16122 non-null  object
#  50  LCB                       16122 non-null  object
#  51  CB                        16122 non-null  object
#  52  RCB                       16122 non-null  object
#  53  RB                        16122 non-null  object
#  54  Crossing                  18159 non-null  float64
#  55  Finishing                 18159 non-null  float64
#  56  HeadingAccuracy           18159 non-null  float64
#  57  ShortPassing              18159 non-null  float64
#  58  Volleys                   18159 non-null  float64
#  59  Dribbling                 18159 non-null  float64
#  60  Curve                     18159 non-null  float64
#  61  FKAccuracy                18159 non-null  float64
#  62  LongPassing               18159 non-null  float64
#  63  BallControl               18159 non-null  float64
#  64  Acceleration              18159 non-null  float64
#  65  SprintSpeed               18159 non-null  float64
#  66  Agility                   18159 non-null  float64
#  67  Reactions                 18159 non-null  float64
#  68  Balance                   18159 non-null  float64
#  69  ShotPower                 18159 non-null  float64
#  70  Jumping                   18159 non-null  float64
#  71  Stamina                   18159 non-null  float64
#  72  Strength                  18159 non-null  float64
#  73  LongShots                 18159 non-null  float64
#  74  Aggression                18159 non-null  float64
#  75  Interceptions             18159 non-null  float64
#  76  Positioning               18159 non-null  float64
#  77  Vision                    18159 non-null  float64
#  78  Penalties                 18159 non-null  float64
#  79  Composure                 18159 non-null  float64
#  80  Marking                   18159 non-null  float64
#  81  StandingTackle            18159 non-null  float64
#  82  SlidingTackle             18159 non-null  float64
#  83  GKDiving                  18159 non-null  float64
#  84  GKHandling                18159 non-null  float64
#  85  GKKicking                 18159 non-null  float64
#  86  GKPositioning             18159 non-null  float64
#  87  GKReflexes                18159 non-null  float64
#  88  Release Clause            16643 non-null  object
# dtypes: float64(38), int64(6), object(45)
# memory usage: 12.4+ MB

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Unnamed: 0           0
# ID                   0
# Name                 0
# Age                  0
# Photo                0
#                   ...
# GKHandling          48
# GKKicking           48
# GKPositioning       48
# GKReflexes          48
# Release Clause    1564
# Length: 89, dtype: int64

# %%
data.isnull().any()
# Out:
# Unnamed: 0        False
# ID                False
# Name              False
# Age               False
# Photo             False
#                   ...
# GKHandling         True
# GKKicking          True
# GKPositioning      True
# GKReflexes         True
# Release Clause     True
# Length: 89, dtype: bool

# %%
#Data Cleaning
data['ShortPassing'].fillna(data['ShortPassing'].mean(), inplace=True)
data['Volleys'].fillna(data['Volleys'].mean(), inplace=True)
data['Dribbling'].fillna(data['Dribbling'].mean(), inplace=True)
data['Curve'].fillna(data['Curve'].mean(), inplace=True)
data['FKAccuracy'].fillna(data['FKAccuracy'].mean(), inplace=True)
data['LongPassing'].fillna(data['LongPassing'].mean(), inplace= True)
data['BallControl'].fillna(data['BallControl'].mean(), inplace=True)
data['HeadingAccuracy'].fillna(data['HeadingAccuracy'].mean(), inplace=True)
data['Finishing'].fillna(data['Finishing'].mean(), inplace=True)
data['Crossing'].fillna(data['Crossing'].mean(), inplace=True)
data['Weight'].fillna('200lbs', inplace=True)
data['Contract Valid Until'].fillna(2019, inplace=True)
data['Height'].fillna("5'11", inplace=True)
data['Loaned From'].fillna('None', inplace=True)
data['Joined'].fillna('Jul 1 2018', inplace=True)
data['Jersey Number'].fillna(8, inplace=True)
data['Body Type'].fillna('Normal', inplace=True)
data['Position'].fillna('ST', inplace=True)
data['Club'].fillna('No Club', inplace=True)
data['Work Rate'].fillna('Medium/ Medium', inplace= True)
data['Skill Moves'].fillna(data['Skill Moves'].median(), inplace=True)
data['Weak Foot'].fillna(3, inplace=True)
data['Preferred Foot'].fillna('Right', inplace=True)
data['International Reputation'].fillna(1, inplace=True)
data['Wage'].fillna('€200K', inplace= True)

# %%
data.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# 3    Manchester United  ...      68.0    15.0           21.0           13.0
# 4      Manchester City  ...      88.0    68.0           58.0           51.0
#
#   GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0      6.0        11.0       15.0           14.0        8.0        €226.5M
# 1      7.0        11.0       15.0           14.0       11.0        €127.1M
# 2      9.0         9.0       15.0           15.0       11.0        €228.1M
# 3     90.0        85.0       87.0           88.0       94.0        €138.6M
# 4     15.0        13.0        5.0           10.0       13.0        €196.4M
#
# [5 rows x 89 columns]

# %%
data.fillna(0, inplace=True)

# %%
def defending(data):
    return int(round((data[['Marking', 'StandingTackle',
                           'SlicingTackle']].mean()).mean()))

def general(data):
    return int(round((data[['HeadingAccuracy', 'Dribbling', 'Curve',
                           'BallControl']].mean()).mean()))

def mental(data):
    return int(round((data[['Agression', 'Interceptions', 'Positioning',
                           'Vision', 'Composure']].mean()).mean()))

def passing(data):
    return int(round((data[['Crossing', 'ShortPassing',
                           'LongPassing']].mean()).mean()))

def power(data):
    return int(round((data[['Balance', 'Jumping', 'Stamina',
                           'Strength']].mean()).mean()))

def mobility(data):
    return int(round((data[['Acceleration', 'SprintSpeed',
                           'Agility', 'Reactions']].mean()),mean()))

def rating(data):
    return int(round((data[['Potential', 'Overall']].mean()).mean()))

def shooting(data):
    return int(round((data[['Finishing', 'Volleys', 'FKAccuracy',
                           'ShortPower', 'LongShots', 'Penalties']].mean()).mean()))

# %%
plt.rcParams['figure.figsize'] = (10,5)
sns.countplot(data['Preferred Foot'], palette= 'pink')
plt.title('Most Preferred Foot of the Players', fontsize= 20)
plt.show()

# %%
labels = ['1', '2', '3', '4', '5']
sizes = data['International Reputation'].value_counts()
colors = plt.cm.copper(np.linspace(0,1,5))
explode = [0.1, 0.1, 0.2, 0.5, 0.9]

plt.rcParams['figure.figsize'] = (9,9)
plt.pie(sizes, labels= labels, colors = colors, explode = explode, shadow= True)
plt.title('International Reputation for the Football Players', fontsize= 20)
plt.legend()
plt.show()

# %%
# labels = ['5', '4', '3', '2', '1']
size = data['Weak Foot'].value_counts()
colors = plt.cm.Wistia(np.linspace(0, 1, 5))
explode = [0, 0, 0, 0, 0.1]

plt.pie(size, labels= labels, colors= colors, explode= explode, shadow= True, startangle = 90)
plt.title('Distribution of Week Foot among Players', fontsize= 25)
plt.legend()
plt.show()

# %%
plt.figure(figsize= (18,8))
plt.style.use('fivethirtyeight')
ax = sns.countplot('Position', data= data, palette= 'bone')
ax.set_xlabel(xlabel= 'Different Position in Football', fontsize=15)
ax.set_ylabel(ylabel= 'Count of Players', fontsize= 15)
ax.set_title(label= 'Comparision of Position and Players', fontsize= 20)
plt.show()

# %%
def extract_value_from(value):
    out = value.replace('lbs', '')
    return float(out)

data['Weight'] = data['Weight'].apply(lambda x : extract_value_from(x))

data['Weight'].head()
# Out:
# 0    159.0
# 1    183.0
# 2    150.0
# 3    168.0
# 4    154.0
# Name: Weight, dtype: float64

# %%
def extract_value_from(Value):
    out = Value.replace('€', '')
    if 'M' in out:
        out = float(out.replace('M', ''))*1000000
    elif 'K' in Value:
        out = float(out.replace('K', ''))*1000
    return float(out)

# %%
data['Value'] = data['Value'].apply(lambda x: extract_value_from(x))
data['Wage'] = data['Wage'].apply(lambda x: extract_value_from(x))


data['Wage'].head()
# Out:
# 0    565000.0
# 1    405000.0
# 2    290000.0
# 3    260000.0
# 4    355000.0
# Name: Wage, dtype: float64

# %%
plt.rcParams['figure.figsize'] = (15,5)
sns.distplot(data['Wage'], color= 'blue')
plt.xlabel('Wage Range for Players', fontsize = 16)
plt.ylabel('Count of the Players', fontsize= 16)
plt.title('Distribution of Wages of the Players', fontsize= 20)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize= (10,8))
ax = sns.countplot(x = 'Skill Moves', data= data, palette= 'pastel')
ax.set_title(label = 'Count of Players on the Basis of their Skill moves', fontsize= 20)
ax.set_xlabel(xlabel= 'Number of Skill Moves', fontsize= 16)
ax.set_ylabel(ylabel = 'Count', fontsize= 16)
plt.show()

# %%
plt.figure(figsize= (13,8))
ax = sns.countplot(x= 'Height', data=data, palette= 'dark')
ax.set_title(label = 'Count of Players on Basis of Height', fontsize=20)
ax.set_xlabel(xlabel= 'Height in Foot per inch', fontsize= 15)
ax.set_ylabel(ylabel= 'Count', fontsize= 15)
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.style.use('classic')
sns.distplot(data['Weight'], color = 'pink')
plt.title('Different Weights of the Players Participating in FIFA 2019', fontsize=20)
plt.xlabel('Heights associated with the Players', fontsize= 16)
plt.ylabel('count of Players', fontsize= 16)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.style.use('classic')


sns.countplot(x = 'Work Rate', data=data, palette= 'hls')
plt.title('Different work rates of Players in FIFA 2019', fontsize=20)
plt.xlabel('Work Rates with Players', fontsize= 15)
plt.ylabel('Count of Players', fontsize= 15)
plt.show()

# %%
x = data.Special
plt.figure(figsize=(12,8))
plt.style.use('tableau-colorblind10')


ax = sns.distplot(x, bins= 58, kde = False, color= 'm')
ax.set_xlabel(xlabel= 'Special score range', fontsize= 15)
ax.set_ylabel(ylabel = 'Count of the Player', fontsize= 15)
ax.set_title(label ="Histogram for the Speciality Scores of the Palyers", fontsize= 20)
plt.show()

# %%
x = data.Potential
plt.figure(figsize= (12,8))
plt.style.use('seaborn-paper')

#potential score by players in FIFA 2019
ax = sns.distplot(x, bins= 58, kde = False, color= 'y')
ax.set_xlabel(xlabel = "Player\'s Potential Scores", fontsize= 15)
ax.set_ylabel(ylabel = "Number of Players", fontsize= 15)
ax.set_title(label = "Histogram of Players", fontsize= 20)
plt.show()

# %%
sns.set(style = 'dark', palette = "deep", color_codes = True)#overall scores by players in FIFA 2019
x = data.Overall
plt.figure(figsize=(12,8))
plt.style.use('ggplot')


ax = sns.distplot(x, bins= 52, kde = False, color= 'r')
ax.set_xlabel(xlabel = "Player\'s Scores", fontsize = 15)
ax.set_ylabel(ylabel= "Number of Player\'s ", fontsize= 15)
ax.set_title(label = "Histogram of Palyers Overall Scores", fontsize= 20)

plt.show()

# %%
plt.style.use('dark_background')
data['Nationality'].value_counts().head(80).plot.bar(color= 'orange', figsize= (20,7))
plt.title('Different Nations Participating in FIFA 2019', fontsize= 30, fontweight= 20)
plt.xlabel('Name of the Country')
plt.ylabel('Count')
plt.show()

# %%
sns.set(style = 'dark', palette=  'colorblind', color_codes = True)
x = data.Age
plt.figure(figsize= (15,8))
ax = sns.distplot(x, bins= 58, kde = False, color= 'g')
ax.set_xlabel(xlabel= "Player\'s Age", fontsize= 15)
ax.set_ylabel(ylabel= "Number of Players", fontsize= 15)
ax.set_title(label = "Histogram of Players Age", fontsize= 20)
plt.show()

# %%
selected_columns = ['Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club', 'Value',
                   'Wage', 'Special', 'Preferred Foot', 'International Reputation', 'Weak Foot',
                   'Skill Moves', 'Work Rate', 'Body Type', 'Position', 'Height', 'Weight',
                   'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
                   'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
                   'SprintSpeed', 'Stamina', 'Strength', 'Longshots', 'Aggression',
                   'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure', 'Marking',
                   'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling', 'GKKicking',
                   'GKPositioning', 'GKReflexes', 'Release Clause']

data_selected = pd.DataFrame(data, columns= selected_columns)
data_selected.columns
# Out:
# Index(['Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club', 'Value',
#        'Wage', 'Special', 'Preferred Foot', 'International Reputation',
#        'Weak Foot', 'Skill Moves', 'Work Rate', 'Body Type', 'Position',
#        'Height', 'Weight', 'Finishing', 'HeadingAccuracy', 'ShortPassing',
#        'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing',
#        'BallControl', 'Acceleration', 'SprintSpeed', 'Stamina', 'Strength',
#        'Longshots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle',
#        'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes',
#        'Release Clause'],
#       dtype='object')

# %%
data_selected.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0           L. Messi   31   Argentina       94         94
# 1  Cristiano Ronaldo   33    Portugal       94         94
# 2          Neymar Jr   26      Brazil       92         93
# 3             De Gea   27       Spain       91         93
# 4       K. De Bruyne   27     Belgium       91         92
#
#                   Club        Value      Wage  Special Preferred Foot  ...  \
# 0         FC Barcelona  110500000.0  565000.0     2202           Left  ...
# 1             Juventus   77000000.0  405000.0     2228          Right  ...
# 2  Paris Saint-Germain  118500000.0  290000.0     2143          Right  ...
# 3    Manchester United   72000000.0  260000.0     1471          Right  ...
# 4      Manchester City  102000000.0  355000.0     2281          Right  ...
#
#    Composure  Marking  StandingTackle SlidingTackle GKDiving GKHandling  \
# 0       96.0     33.0            28.0          26.0      6.0       11.0
# 1       95.0     28.0            31.0          23.0      7.0       11.0
# 2       94.0     27.0            24.0          33.0      9.0        9.0
# 3       68.0     15.0            21.0          13.0     90.0       85.0
# 4       88.0     68.0            58.0          51.0     15.0       13.0
#
#   GKKicking  GKPositioning  GKReflexes  Release Clause
# 0      15.0           14.0         8.0         €226.5M
# 1      15.0           14.0        11.0         €127.1M
# 2      15.0           15.0        11.0         €228.1M
# 3      87.0           88.0        94.0         €138.6M
# 4       5.0           10.0        13.0         €196.4M
#
# [5 rows x 47 columns]

# %%
plt.rcParams['figure.figsize'] = (20,7)
plt.style.use('seaborn-dark-palette')


sns.boxenplot(data['Overall'], data['Age'], hue= data['Preferred Foot'], palette= 'Greys')
plt.title('Comparsion of Overall Scores and Age wrt Preferred Foot', fontsize= 20)
plt.show()

# %%
data_selected.sample(10)
# Out:
#                     Name  Age   Nationality  Overall  Potential  \
# 15969       C. Gutiérrez   19        Mexico       58         73
# 7489   N. Moumi Ngamaleu   23      Cameroon       68         74
# 5367           M. Tahrat   28       Algeria       70         70
# 16574       J. Hernandez   22        Mexico       57         65
# 6273           R. Taylor   33       England       69         69
# 1069           Y. Sabaly   25       Senegal       77         80
# 2081      M. Krohn-Dehli   35       Denmark       74         74
# 9335             H. Zuck   27       Germany       66         66
# 12810       M. Al Saiari   25  Saudi Arabia       63         65
# 7073      A. Tighadouini   25       Morocco       68         69
#
#                            Club      Value     Wage  Special Preferred Foot  \
# 15969                  U.N.A.M.   270000.0   1000.0     1480          Right
# 7489             BSC Young Boys  1200000.0   8000.0     1729          Right
# 5367        Racing Club de Lens  1400000.0   6000.0     1514          Right
# 16574            Real Salt Lake   150000.0   1000.0     1528          Right
# 6273             Fleetwood Town   400000.0   5000.0     1930          Right
# 1069   FC Girondins de Bordeaux  9000000.0  35000.0     1842          Right
# 2081     Deportivo de La Coruña  2400000.0   7000.0     2001          Right
# 9335       1. FC Kaiserslautern   675000.0   2000.0     1618           Left
# 12810                  Al Hazem   450000.0   6000.0     1594          Right
# 7073                 Esbjerg fB  1100000.0   4000.0     1815          Right
#
#        ...  Composure  Marking  StandingTackle SlidingTackle GKDiving  \
# 15969  ...       60.0     34.0            30.0          35.0     11.0
# 7489   ...       58.0     32.0            27.0          28.0      7.0
# 5367   ...       60.0     67.0            71.0          69.0     15.0
# 16574  ...       54.0     35.0            31.0          32.0     11.0
# 6273   ...       70.0     67.0            70.0          69.0     14.0
# 1069   ...       70.0     73.0            80.0          77.0      9.0
# 2081   ...       69.0     63.0            68.0          61.0     10.0
# 9335   ...       58.0     25.0            31.0          36.0      7.0
# 12810  ...       55.0     33.0            28.0          35.0      7.0
# 7073   ...       64.0     42.0            37.0          24.0     11.0
#
#       GKHandling GKKicking  GKPositioning  GKReflexes  Release Clause
# 15969       14.0      14.0            7.0        13.0           €628K
# 7489        15.0      10.0           12.0         9.0           €2.1M
# 5367         9.0       6.0           13.0        10.0           €2.5M
# 16574        6.0       5.0            8.0         6.0           €255K
# 6273         9.0       6.0            6.0         8.0           €700K
# 1069        11.0       8.0           15.0        11.0          €17.8M
# 2081         8.0      15.0           16.0        11.0           €3.8M
# 9335        11.0       7.0            9.0         8.0           €979K
# 12810        7.0      10.0           10.0         7.0               0
# 7073         6.0      11.0           12.0         8.0               0
#
# [10 rows x 47 columns]

# %%
plt.rcParams['figure.figsize'] = (30,20)
sns.heatmap(data_selected[['Age', 'Nationality', 'Overall', 'Potential', 'Club', 'Value',
                          'Wage', 'Special', 'Preferred Foot', 'International Reputation', 'Weak Foot',
                          'Skill Moves', 'Work Rate', 'Body Type', 'Position', 'Height', 'Weight',
                          'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve',
                          'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
                          'SprintSpeed', 
                          'Stamina', 'Strength', 'Aggression',
                          'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
                          'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
                          'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause']].corr(), annot= True)

plt.title('Histogram of the Dataset', fontsize= 20)
plt.show()

# %%
data.iloc[data.groupby(data['Position'])['Overall'].idxmax()][['Position', 'Name', 'Age',
                                                              'Club', 'Nationality']].style.background_gradient('Reds')
# Out:
# <style  type="text/css" >
# #T_e3a25_row0_col2,#T_e3a25_row4_col2,#T_e3a25_row5_col2,#T_e3a25_row10_col2,#T_e3a25_row11_col2,#T_e3a25_row19_col2{
#             background-color:  #f44f39;
#             color:  #000000;
#         }#T_e3a25_row1_col2,#T_e3a25_row18_col2{
#             background-color:  #8a0812;
#             color:  #f1f1f1;
#         }#T_e3a25_row2_col2,#T_e3a25_row12_col2{
#             background-color:  #d52221;
#             color:  #f1f1f1;
#         }#T_e3a25_row3_col2,#T_e3a25_row15_col2,#T_e3a25_row20_col2{
#             background-color:  #fc8161;
#             color:  #000000;
#         }#T_e3a25_row6_col2,#T_e3a25_row14_col2{
#             background-color:  #fb694a;
#             color:  #000000;
#         }#T_e3a25_row7_col2,#T_e3a25_row16_col2{
#             background-color:  #bf151b;
#             color:  #f1f1f1;
#         }#T_e3a25_row8_col2,#T_e3a25_row26_col2{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_e3a25_row9_col2,#T_e3a25_row17_col2{
#             background-color:  #ea362a;
#             color:  #f1f1f1;
#         }#T_e3a25_row13_col2,#T_e3a25_row21_col2,#T_e3a25_row23_col2{
#             background-color:  #aa1016;
#             color:  #f1f1f1;
#         }#T_e3a25_row22_col2{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }#T_e3a25_row24_col2{
#             background-color:  #fcaf93;
#             color:  #000000;
#         }#T_e3a25_row25_col2{
#             background-color:  #fc9879;
#             color:  #000000;
#         }</style><table id="T_e3a25_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Position</th>        <th class="col_heading level0 col1" >Name</th>        <th class="col_heading level0 col2" >Age</th>        <th class="col_heading level0 col3" >Club</th>        <th class="col_heading level0 col4" >Nationality</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e3a25_level0_row0" class="row_heading level0 row0" >17</th>
#                         <td id="T_e3a25_row0_col0" class="data row0 col0" >CAM</td>
#                         <td id="T_e3a25_row0_col1" class="data row0 col1" >A. Griezmann</td>
#                         <td id="T_e3a25_row0_col2" class="data row0 col2" >27</td>
#                         <td id="T_e3a25_row0_col3" class="data row0 col3" >Atlético Madrid</td>
#                         <td id="T_e3a25_row0_col4" class="data row0 col4" >France</td>
#             </tr>
#             <tr>
#                         <th id="T_e3a25_level0_row1" class="row_heading level0 row1" >12</th>
#                         <td id="T_e3a25_row1_col0" class="data row1 col0" >CB</td>
#                         <td id="T_e3a25_row1_col1" class="data row1 col1" >D. Godín</td>
#                         <td id="T_e3a25_row1_col2" class="data row1 col2" >32</td>
#                         <td id="T_e3a25_row1_col3" class="data row1 col3" >Atlético Madrid</td>
#                         <td id="T_e3a25_row1_col4" class="data row1 col4" >Uruguay</td>
#             </tr>
#             <tr>
#                         <th id="T_e3a25_level0_row2" class="row_heading level0 row2" >20</th>
#                         <td id="T_e3a25_row2_col0" class="data row2 col0" >CDM</td>
#                         <td id="T_e3a25_row2_col1" class="data row2 col1" >Sergio Busquets</td>
#                         <td id="T_e3a25_row2_col2" class="data row2 col2" >29</td>
#                         <td id="T_e3a25_row2_col3" class="data row2 col3" >FC Barcelona</td>
#                         <td id="T_e3a25_row2_col4" class="data row2 col4" >Spain</td>
#             </tr>
#             <tr>
#                         <th id="T_e3a25_level0_row3" class="row_heading level0 row3" >271</th>
#                         <td id="T_e3a25_row3_col0" class="data row3 col0" >CF</td>
#                         <td id="T_e3a25_row3_col1" class="data row3 col1" >Luis Alberto</td>
#                         <td id="T_e3a25_row3_col2" class="data row3 col2" >25</td>
#                         <td id="T_e3a25_row3_col3" class="data row3 col3" >Lazio</td>
#                         <td id="T_e3a25_row3_col4" class="data row3 col4" >Spain</td>
#             </tr>
#             <tr>
#                         <th id="T_e3a25_level0_row4" class="row_heading level0 row4" >67</th>
#                         <td id="T_e3a25_row4_col0" class="data row4 col0" >CM</td>
#                         <td id="T_e3a25_row4_col1" class="data row4 col1" >Thiago</td>
#                         <td id="T_e3a25_row4_col2" class="data row4 col2" >27</td>
#                         <td id="T_e3a25_row4_col3" class="data row4 col3" >FC Bayern München</td>
#                         <td id="T_e3a25_row4_col4" class="data row4 col4" >Spain</td>
#             </tr>
#             <tr>
#                         <th id="T_e3a25_level0_row5" class="row_heading level0 row5" >3</th>
#                         <td id="T_e3a25_row5_col0" class="data row5 col0" >GK</td>
#                         <td id="T_e3a25_row5_col1" class="data row5 col1" >De Gea</td>
#                         <td id="T_e3a25_row5_col2" class="data row5 col2" >27</td>
#                         <td id="T_e3a25_row5_col3" class="data row5 col3" >Manchester United</td>
#                         <td id="T_e3a25_row5_col4" class="data row5 col4" >Spain</td>
#             </tr>
#             <tr>
#                         <th id="T_e3a25_level0_row6" class="row_heading level0 row6" >28</th>
#                         <td id="T_e3a25_row6_col0" class="data row6 col0" >LAM</td>
#                         <td id="T_e3a25_row6_col1" class="data row6 col1" >J. Rodríguez</td>
#                         <td id="T_e3a25_row6_col2" class="data row6 col2" >26</td>
#                         <td id="T_e3a25_row6_col3" class="data row6 col3" >FC Bayern München</td>
#                         <td id="T_e3a25_row6_col4" class="data row6 col4" >Colombia</td>
#             </tr>
#             <tr>
#                         <th id="T_e3a25_level0_row7" class="row_heading level0 row7" >35</th>
#                         <td id="T_e3a25_row7_col0" class="data row7 col0" >LB</td>
#                         <td id="T_e3a25_row7_col1" class="data row7 col1" >Marcelo</td>
#                         <td id="T_e3a25_row7_col2" class="data row7 col2" >30</td>
#                         <td id="T_e3a25_row7_col3" class="data row7 col3" >Real Madrid</td>
#                         <td id="T_e3a25_row7_col4" class="data row7 col4" >Brazil</td>
#             </tr>
#             <tr>
#                         <th id="T_e3a25_level0_row8" class="row_heading level0 row8" >24</th>
#                         <td id="T_e3a25_row8_col0" class="data row8 col0" >LCB</td>
#                         <td id="T_e3a25_row8_col1" class="data row8 col1" >G. Chiellini</td>
#                         <td id="T_e3a25_row8_col2" class="data row8 col2" >33</td>
#                         <td id="T_e3a25_row8_col3" class="data row8 col3" >Juventus</td>
#                         <td id="T_e3a25_row8_col4" class="data row8 col4" >Italy</td>
#             </tr>
#             <tr>
#                         <th id="T_e3a25_level0_row9" class="row_heading level0 row9" >11</th>
#                         <td id="T_e3a25_row9_col0" class="data row9 col0" >LCM</td>
#                         <td id="T_e3a25_row9_col1" class="data row9 col1" >T. Kroos</td>
#                         <td id="T_e3a25_row9_col2" class="data row9 col2" >28</td>
#                         <td id="T_e3a25_row9_col3" class="data row9 col3" >Real Madrid</td>
#                         <td id="T_e3a25_row9_col4" class="data row9 col4" >Germany</td>
#             </tr>
#             <tr>
#                         <th id="T_e3a25_level0_row10" class="row_heading level0 row10" >14</th>
#                         <td id="T_e3a25_row10_col0" class="data row10 col0" >LDM</td>
#                         <td id="T_e3a25_row10_col1" class="data row10 col1" >N. Kanté</td>
#                         <td id="T_e3a25_row10_col2" class="data row10 col2" >27</td>
#                         <td id="T_e3a25_row10_col3" class=

# %%
data.iloc[data.groupby(data['Position'])['Potential'].idxmax()][['Position', 'Name',
                                                                'Age', 'Club', 'Nationality']].style.background_gradient('Blues')
# Out:
# <style  type="text/css" >
# #T_df82a_row0_col2,#T_df82a_row2_col2,#T_df82a_row6_col2,#T_df82a_row14_col2{
#             background-color:  #6aaed6;
#             color:  #000000;
#         }#T_df82a_row1_col2,#T_df82a_row3_col2,#T_df82a_row11_col2,#T_df82a_row15_col2,#T_df82a_row17_col2{
#             background-color:  #a4cce3;
#             color:  #000000;
#         }#T_df82a_row4_col2,#T_df82a_row8_col2{
#             background-color:  #bad6eb;
#             color:  #000000;
#         }#T_df82a_row5_col2,#T_df82a_row10_col2,#T_df82a_row19_col2{
#             background-color:  #539ecd;
#             color:  #000000;
#         }#T_df82a_row7_col2{
#             background-color:  #1967ad;
#             color:  #f1f1f1;
#         }#T_df82a_row9_col2{
#             background-color:  #3d8dc4;
#             color:  #000000;
#         }#T_df82a_row12_col2,#T_df82a_row25_col2{
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }#T_df82a_row13_col2,#T_df82a_row21_col2,#T_df82a_row23_col2{
#             background-color:  #0b559f;
#             color:  #f1f1f1;
#         }#T_df82a_row16_col2,#T_df82a_row20_col2{
#             background-color:  #89bedc;
#             color:  #000000;
#         }#T_df82a_row18_col2{
#             background-color:  #084387;
#             color:  #f1f1f1;
#         }#T_df82a_row22_col2{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_df82a_row24_col2{
#             background-color:  #cde0f1;
#             color:  #000000;
#         }#T_df82a_row26_col2{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }</style><table id="T_df82a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Position</th>        <th class="col_heading level0 col1" >Name</th>        <th class="col_heading level0 col2" >Age</th>        <th class="col_heading level0 col3" >Club</th>        <th class="col_heading level0 col4" >Nationality</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_df82a_level0_row0" class="row_heading level0 row0" >31</th>
#                         <td id="T_df82a_row0_col0" class="data row0 col0" >CAM</td>
#                         <td id="T_df82a_row0_col1" class="data row0 col1" >C. Eriksen</td>
#                         <td id="T_df82a_row0_col2" class="data row0 col2" >26</td>
#                         <td id="T_df82a_row0_col3" class="data row0 col3" >Tottenham Hotspur</td>
#                         <td id="T_df82a_row0_col4" class="data row0 col4" >Denmark</td>
#             </tr>
#             <tr>
#                         <th id="T_df82a_level0_row1" class="row_heading level0 row1" >42</th>
#                         <td id="T_df82a_row1_col0" class="data row1 col0" >CB</td>
#                         <td id="T_df82a_row1_col1" class="data row1 col1" >S. Umtiti</td>
#                         <td id="T_df82a_row1_col2" class="data row1 col2" >24</td>
#                         <td id="T_df82a_row1_col3" class="data row1 col3" >FC Barcelona</td>
#                         <td id="T_df82a_row1_col4" class="data row1 col4" >France</td>
#             </tr>
#             <tr>
#                         <th id="T_df82a_level0_row2" class="row_heading level0 row2" >27</th>
#                         <td id="T_df82a_row2_col0" class="data row2 col0" >CDM</td>
#                         <td id="T_df82a_row2_col1" class="data row2 col1" >Casemiro</td>
#                         <td id="T_df82a_row2_col2" class="data row2 col2" >26</td>
#                         <td id="T_df82a_row2_col3" class="data row2 col3" >Real Madrid</td>
#                         <td id="T_df82a_row2_col4" class="data row2 col4" >Brazil</td>
#             </tr>
#             <tr>
#                         <th id="T_df82a_level0_row3" class="row_heading level0 row3" >350</th>
#                         <td id="T_df82a_row3_col0" class="data row3 col0" >CF</td>
#                         <td id="T_df82a_row3_col1" class="data row3 col1" >A. Milik</td>
#                         <td id="T_df82a_row3_col2" class="data row3 col2" >24</td>
#                         <td id="T_df82a_row3_col3" class="data row3 col3" >Napoli</td>
#                         <td id="T_df82a_row3_col4" class="data row3 col4" >Poland</td>
#             </tr>
#             <tr>
#                         <th id="T_df82a_level0_row4" class="row_heading level0 row4" >78</th>
#                         <td id="T_df82a_row4_col0" class="data row4 col0" >CM</td>
#                         <td id="T_df82a_row4_col1" class="data row4 col1" >S. Milinković-Savić</td>
#                         <td id="T_df82a_row4_col2" class="data row4 col2" >23</td>
#                         <td id="T_df82a_row4_col3" class="data row4 col3" >Lazio</td>
#                         <td id="T_df82a_row4_col4" class="data row4 col4" >Serbia</td>
#             </tr>
#             <tr>
#                         <th id="T_df82a_level0_row5" class="row_heading level0 row5" >3</th>
#                         <td id="T_df82a_row5_col0" class="data row5 col0" >GK</td>
#                         <td id="T_df82a_row5_col1" class="data row5 col1" >De Gea</td>
#                         <td id="T_df82a_row5_col2" class="data row5 col2" >27</td>
#                         <td id="T_df82a_row5_col3" class="data row5 col3" >Manchester United</td>
#                         <td id="T_df82a_row5_col4" class="data row5 col4" >Spain</td>
#             </tr>
#             <tr>
#                         <th id="T_df82a_level0_row6" class="row_heading level0 row6" >28</th>
#                         <td id="T_df82a_row6_col0" class="data row6 col0" >LAM</td>
#                         <td id="T_df82a_row6_col1" class="data row6 col1" >J. Rodríguez</td>
#                         <td id="T_df82a_row6_col2" class="data row6 col2" >26</td>
#                         <td id="T_df82a_row6_col3" class="data row6 col3" >FC Bayern München</td>
#                         <td id="T_df82a_row6_col4" class="data row6 col4" >Colombia</td>
#             </tr>
#             <tr>
#                         <th id="T_df82a_level0_row7" class="row_heading level0 row7" >35</th>
#                         <td id="T_df82a_row7_col0" class="data row7 col0" >LB</td>
#                         <td id="T_df82a_row7_col1" class="data row7 col1" >Marcelo</td>
#                         <td id="T_df82a_row7_col2" class="data row7 col2" >30</td>
#                         <td id="T_df82a_row7_col3" class="data row7 col3" >Real Madrid</td>
#                         <td id="T_df82a_row7_col4" class="data row7 col4" >Brazil</td>
#             </tr>
#             <tr>
#                         <th id="T_df82a_level0_row8" class="row_heading level0 row8" >77</th>
#                         <td id="T_df82a_row8_col0" class="data row8 col0" >LCB</td>
#                         <td id="T_df82a_row8_col1" class="data row8 col1" >M. Škriniar</td>
#                         <td id="T_df82a_row8_col2" class="data row8 col2" >23</td>
#                         <td id="T_df82a_row8_col3" class="data row8 col3" >Inter</td>
#                         <td id="T_df82a_row8_col4" class="data row8 col4" >Slovakia</td>
#             </tr>
#             <tr>
#                         <th id="T_df82a_level0_row9" class="row_heading level0 row9" >11</th>
#                         <td id="T_df82a_row9_col0" class="data row9 col0" >LCM</td>
#                         <td id="T_df82a_row9_col1" class="data row9 col1" >T. Kroos</td>
#                         <td id="T_df82a_row9_col2" class="data row9 col2" >28</td>
#                         <td id="T_df82a_row9_col3" class="data row9 col3" >Real Madrid</td>
#                         <td id="T_df82a_row9_col4" class="data row9 col4" >Germany</td>
#             </tr>
#             <tr>
#                         <th id="T_df82a_level0_row10" class="row_heading level0 row10" >14</th>
#                         <td id="T_df82a_row10_col0" class="data row10 col0" >LDM</td>
#                         <td id="T_df82a_row10_col1" class="data row10 col1" >N. Kanté</td>
#                         <td id="T_df82a_row10_col2" class="data row10 col2

# %%
data['Nationality'].value_counts().head(10)
# Out:
# England        1662
# Germany        1198
# Spain          1072
# Argentina       937
# France          914
# Brazil          827
# Italy           702
# Colombia        618
# Japan           478
# Netherlands     453
# Name: Nationality, dtype: int64

# %%
some_countries = ('England', 'Germany', 'Spain', 'Argentina', 'France', 'Brazil', 'Italy', 'Columbia')

data_countries = data.loc[data['Nationality'].isin(some_countries) & data['Weight']]

plt.rcParams['figure.figsize'] = (15,7)

ax = sns.violinplot(x = data_countries['Nationality'], y = data_countries['Weight'], palette= 'Reds')

ax.set_xlabel(xlabel= 'Countries', fontsize= 9)
ax.set_ylabel(ylabel= 'Weight in lbs', fontsize= 9)
ax.set_title(label = 'Distribution of Weight of Players from different countries', fontsize= 20)

plt.show()

# %%
data.head(5)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club  ... Composure  Marking  StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0     33.0            28.0           26.0
# 1             Juventus  ...      95.0     28.0            31.0           23.0
# 2  Paris Saint-Germain  ...      94.0     27.0            24.0           33.0
# 3    Manchester United  ...      68.0     15.0            21.0           13.0
# 4      Manchester City  ...      88.0     68.0            58.0           51.0
#
#   GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0      6.0        11.0       15.0           14.0        8.0        €226.5M
# 1      7.0        11.0       15.0           14.0       11.0        €127.1M
# 2      9.0         9.0       15.0           15.0       11.0        €228.1M
# 3     90.0        85.0       87.0           88.0       94.0        €138.6M
# 4     15.0        13.0        5.0           10.0       13.0        €196.4M
#
# [5 rows x 89 columns]

# %%
data.shape
# Out:
# (18207, 89)

# %%
some_countries = ('England', 'Germany', 'Spain', 'Argentina', 'France', 'Brazil', 'Italy', 'Columbia')

data_countries = data.loc[data['Nationality'].isin(some_countries) & data['Overall']]

plt.rcParams['figure.figsize'] = (15,7)
ax = sns.barplot(x= data_countries['Nationality'], y= data_countries['Overall'], palette= 'spring')
ax.set_xlabel(xlabel= 'Countries', fontsize= 10)
ax.set_ylabel(ylabel= 'Overall Score', fontsize= 10)
ax.set_title(label = 'Distribution of overall scores of players from different countries', fontsize= 20)

plt.show()

# %%
some_countries = ('England', 'Germany', 'Spain', 'Argentina', 'France', 'Brazil', 'Italy', 'Columbia')
data_countries = data.loc[data['Nationality'].isin(some_countries) & data['Wage']]#find out nation players with  wage

plt.rcParams['figure.figsize'] = (15,7)
ax = sns.barplot(x= data_countries['Nationality'], y= data_countries['Wage'], palette= 'Purples')
ax.set_xlabel(xlabel= 'Countries', fontsize= 10)
ax.set_ylabel(ylabel= 'Wage', fontsize= 10)
ax.set_title(label= 'Distribution of Wages of different countries', fontsize=20)
plt.show()

# %%
some_countries = ('England', 'Germay', 'Spain', 'Argentina', 'France', 'Brazil', 'Italy', 'Columbai')
data_countries = data.loc[data['Nationality'].isin(some_countries) & data['International Reputation']]

plt.rcParams['figure.figsize'] = (15,7)
ax = sns.boxenplot(x= data_countries['Nationality'], y= data_countries['International Reputation'], palette= 'autumn')
ax.set_title(label= 'Distribution of International Reputation of Players from different Countries', fontsize= 20)
ax.set_ylabel(ylabel= 'Distribution of Reputation', fontsize= 15)
ax.set_xlabel(xlabel= 'Countries', fontsize=15)

plt.show()

# %%
data['Club'].value_counts().head(10)
# Out:
# No Club                    241
# Empoli                      33
# Manchester City             33
# Southampton                 33
# CD Leganés                  33
# Newcastle United            33
# Wolverhampton Wanderers     33
# Everton                     33
# Chelsea                     33
# Manchester United           33
# Name: Club, dtype: int64

# %%
some_clubs = ('CD Legends', 'Southampton', 'RC Celta', 'Empoli', 'Fortuna Düsseldorf', 'Manchestar City', 'Tottemham Hotspur',
             'FC Barcelona', 'Valencia CF', 'Chelsea', 'Real Madrid')

data_clubs = data.loc[data['Club'].isin(some_clubs) & data['Overall']]

plt.rcParams['figure.figsize'] = (15,8)
ax = sns.boxplot(x= data_clubs['Club'], y= data_clubs['Overall'], palette= 'inferno')
ax.set_xlabel(xlabel = "Some Popular Clubs", fontsize= 10)
ax.set_title(label = "Distribution of Overall Score in Different popular Clubs", fontsize= 20)
ax.set_ylabel(ylabel = "Overall Score", fontsize=10)

plt.show()

# %%
some_clubs = ('CD Legends', 'Southampton', 'RC Celta', 'Empoli', 'Fortuna Düsseldorf', 'Manchestar City',
             'Tottenham Hotspur', 'FC Barcelona', 'Valencia CF', 'Chelsea', 'Real Madrid')


data_clubs = data.loc[data['Club'].isin(some_clubs) & data['Wage']]

plt.rcParams['figure.figsize'] = (15,8)
ax = sns.boxplot(x = 'Club', y = 'Wage', data = data_clubs, palette= 'Reds')
ax.set_xlabel(xlabel= 'Names of popular CLubs', fontsize= 10)
ax.set_title(label= 'Distribution of Wages in some Popular Clubs', fontsize= 20)
ax.set_ylabel(ylabel = 'Distribution', fontsize = 10)
plt.xticks(rotation= 90)

plt.show()

# %%
some_countries
# Out:
# ('England',
#  'Germay',
#  'Spain',
#  'Argentina',
#  'France',
#  'Brazil',
#  'Italy',
#  'Columbai')

# %%
some_clubs
# Out:
# ('CD Legends',
#  'Southampton',
#  'RC Celta',
#  'Empoli',
#  'Fortuna Düsseldorf',
#  'Manchestar City',
#  'Tottenham Hotspur',
#  'FC Barcelona',
#  'Valencia CF',
#  'Chelsea',
#  'Real Madrid')

# %%
player_features = ('Acceleration', 'Aggression', 'Agility',
                  'Balance', 'BallControl', 'Composure',
                  'Crossing', 'Dribbling', 'FKAccuracy',
                  'Finishing', 'GKDiving', 'GKHandling',
                  'GKKicking', 'GKPositioning', 'GKReflexes',
                  'HeadingAccuracy', 'Interceptions', 'Jumping',
                  'LongPassing', 'LongShots', 'Marking', 'Penalties')

for i, val in data.groupby(data['Position'])[player_features].mean().iterrows():
    print('Position {}: {}, {}, {}'.format(i, *tuple(val.nlargest(4).index)))
# Out:
# Position CAM: Balance, Agility, Acceleration
# Position CB: Jumping, Aggression, HeadingAccuracy
# Position CDM: Aggression, Jumping, Balance
# Position CF: Agility, Balance, Acceleration
# Position CM: Balance, Agility, Acceleration
# Position GK: GKReflexes, GKDiving, GKPositioning
# Position LAM: Agility, Balance, Acceleration
# Position LB: Acceleration, Balance, Agility
# Position LCB: Jumping, Aggression, HeadingAccuracy
# Position LCM: Balance, Agility, BallControl
# Position LDM: Aggression, BallControl, LongPassing
# Position LF: Balance, Agility, Acceleration
# Position LM: Acceleration, Agility, Balance
# Position LS: Acceleration, Agility, Finishing
# Position LW: Acceleration, Agility, Balance
# Position LWB: Acceleration, Agility, Balance
# Position RAM: Agility, Balance, Acceleration
# Position RB: Acceleration, Balance, Jumping
# Position RCB: Jumping, Aggression, HeadingAccuracy
# Position RCM: Agility, Balance, BallControl
# Position RDM: Aggression, Jumping, BallControl
# Position RF: Agility, Acceleration, Balance
# Position RM: Acceleration, Agility, Balance
# Position RS: Acceleration, Agility, Jumping
# Position RW: Acceleration, Agility, Balance
# Position RWB: Acceleration, Agility, Balance
# Position ST: Acceleration, Jumping, Finishing

# %%
player_features
# Out:
# ('Acceleration',
#  'Aggression',
#  'Agility',
#  'Balance',
#  'BallControl',
#  'Composure',
#  'Crossing',
#  'Dribbling',
#  'FKAccuracy',
#  'Finishing',
#  'GKDiving',
#  'GKHandling',
#  'GKKicking',
#  'GKPositioning',
#  'GKReflexes',
#  'HeadingAccuracy',
#  'Interceptions',
#  'Jumping',
#  'LongPassing',
#  'LongShots',
#  'Marking',
#  'Penalties')

# %%
from math import pi

idx = 1
plt.figure(figsize=(15,45))
for position_name, features in data.groupby(data['Position'])[player_features].mean().iterrows():
    top_features = dict(features.nlargest(5))
    
    
    categories = top_features.keys()
    N = len(categories)
    
    
    values = list(top_features.values())
    values += values[:1]
    
    angles = [n / float(N) * 2 * pi for n in range(N)]
    angles += angles[:1]
    
    ax = plt.subplot(9, 3, idx, polar = True)
    
    plt.xticks(angles[:-1], categories, color= 'grey', size= 8)
    
    
    ax.set_rlabel_position(0)
    plt.yticks([25,50,75], ["25", "50", "75"], color= "grey", size= 7)
    plt.ylim(0,100)
    
    plt.subplots_adjust(hspace = 0.5)
    
    ax.plot(angles, values, 'b', alpha= 0.1)
    
    plt.title(position_name, size= 11, y= 1.1)
    
    idx += 1

# %%
#TOP 10 LEFT FOOT USED FOR GOAL
data[data['Preferred Foot'] == 'Left'][['Name', 'Age', 'Club', 'Nationality']].head(10).style.background_gradient('magma')
# Out:
# <style  type="text/css" >
# #T_e7fb2_row0_col1{
#             background-color:  #fd9668;
#             color:  #000000;
#         }#T_e7fb2_row1_col1{
#             background-color:  #feca8d;
#             color:  #000000;
#         }#T_e7fb2_row2_col1{
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }#T_e7fb2_row3_col1{
#             background-color:  #721f81;
#             color:  #f1f1f1;
#         }#T_e7fb2_row4_col1,#T_e7fb2_row6_col1,#T_e7fb2_row7_col1{
#             background-color:  #440f76;
#             color:  #f1f1f1;
#         }#T_e7fb2_row5_col1{
#             background-color:  #fcfdbf;
#             color:  #000000;
#         }#T_e7fb2_row8_col1{
#             background-color:  #f1605d;
#             color:  #000000;
#         }#T_e7fb2_row9_col1{
#             background-color:  #9e2f7f;
#             color:  #f1f1f1;
#         }</style><table id="T_e7fb2_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Name</th>        <th class="col_heading level0 col1" >Age</th>        <th class="col_heading level0 col2" >Club</th>        <th class="col_heading level0 col3" >Nationality</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e7fb2_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e7fb2_row0_col0" class="data row0 col0" >L. Messi</td>
#                         <td id="T_e7fb2_row0_col1" class="data row0 col1" >31</td>
#                         <td id="T_e7fb2_row0_col2" class="data row0 col2" >FC Barcelona</td>
#                         <td id="T_e7fb2_row0_col3" class="data row0 col3" >Argentina</td>
#             </tr>
#             <tr>
#                         <th id="T_e7fb2_level0_row1" class="row_heading level0 row1" >13</th>
#                         <td id="T_e7fb2_row1_col0" class="data row1 col0" >David Silva</td>
#                         <td id="T_e7fb2_row1_col1" class="data row1 col1" >32</td>
#                         <td id="T_e7fb2_row1_col2" class="data row1 col2" >Manchester City</td>
#                         <td id="T_e7fb2_row1_col3" class="data row1 col3" >Spain</td>
#             </tr>
#             <tr>
#                         <th id="T_e7fb2_level0_row2" class="row_heading level0 row2" >15</th>
#                         <td id="T_e7fb2_row2_col0" class="data row2 col0" >P. Dybala</td>
#                         <td id="T_e7fb2_row2_col1" class="data row2 col1" >24</td>
#                         <td id="T_e7fb2_row2_col2" class="data row2 col2" >Juventus</td>
#                         <td id="T_e7fb2_row2_col3" class="data row2 col3" >Argentina</td>
#             </tr>
#             <tr>
#                         <th id="T_e7fb2_level0_row3" class="row_heading level0 row3" >17</th>
#                         <td id="T_e7fb2_row3_col0" class="data row3 col0" >A. Griezmann</td>
#                         <td id="T_e7fb2_row3_col1" class="data row3 col1" >27</td>
#                         <td id="T_e7fb2_row3_col2" class="data row3 col2" >Atlético Madrid</td>
#                         <td id="T_e7fb2_row3_col3" class="data row3 col3" >France</td>
#             </tr>
#             <tr>
#                         <th id="T_e7fb2_level0_row4" class="row_heading level0 row4" >19</th>
#                         <td id="T_e7fb2_row4_col0" class="data row4 col0" >T. Courtois</td>
#                         <td id="T_e7fb2_row4_col1" class="data row4 col1" >26</td>
#                         <td id="T_e7fb2_row4_col2" class="data row4 col2" >Real Madrid</td>
#                         <td id="T_e7fb2_row4_col3" class="data row4 col3" >Belgium</td>
#             </tr>
#             <tr>
#                         <th id="T_e7fb2_level0_row5" class="row_heading level0 row5" >24</th>
#                         <td id="T_e7fb2_row5_col0" class="data row5 col0" >G. Chiellini</td>
#                         <td id="T_e7fb2_row5_col1" class="data row5 col1" >33</td>
#                         <td id="T_e7fb2_row5_col2" class="data row5 col2" >Juventus</td>
#                         <td id="T_e7fb2_row5_col3" class="data row5 col3" >Italy</td>
#             </tr>
#             <tr>
#                         <th id="T_e7fb2_level0_row6" class="row_heading level0 row6" >26</th>
#                         <td id="T_e7fb2_row6_col0" class="data row6 col0" >M. Salah</td>
#                         <td id="T_e7fb2_row6_col1" class="data row6 col1" >26</td>
#                         <td id="T_e7fb2_row6_col2" class="data row6 col2" >Liverpool</td>
#                         <td id="T_e7fb2_row6_col3" class="data row6 col3" >Egypt</td>
#             </tr>
#             <tr>
#                         <th id="T_e7fb2_level0_row7" class="row_heading level0 row7" >28</th>
#                         <td id="T_e7fb2_row7_col0" class="data row7 col0" >J. Rodríguez</td>
#                         <td id="T_e7fb2_row7_col1" class="data row7 col1" >26</td>
#                         <td id="T_e7fb2_row7_col2" class="data row7 col2" >FC Bayern München</td>
#                         <td id="T_e7fb2_row7_col3" class="data row7 col3" >Colombia</td>
#             </tr>
#             <tr>
#                         <th id="T_e7fb2_level0_row8" class="row_heading level0 row8" >35</th>
#                         <td id="T_e7fb2_row8_col0" class="data row8 col0" >Marcelo</td>
#                         <td id="T_e7fb2_row8_col1" class="data row8 col1" >30</td>
#                         <td id="T_e7fb2_row8_col2" class="data row8 col2" >Real Madrid</td>
#                         <td id="T_e7fb2_row8_col3" class="data row8 col3" >Brazil</td>
#             </tr>
#             <tr>
#                         <th id="T_e7fb2_level0_row9" class="row_heading level0 row9" >36</th>
#                         <td id="T_e7fb2_row9_col0" class="data row9 col0" >G. Bale</td>
#                         <td id="T_e7fb2_row9_col1" class="data row9 col1" >28</td>
#                         <td id="T_e7fb2_row9_col2" class="data row9 col2" >Real Madrid</td>
#                         <td id="T_e7fb2_row9_col3" class="data row9 col3" >Wales</td>
#             </tr>
#     </tbody></table>

# %%
#top right foor used for Goal
data[data['Preferred Foot'] == 'Right'][['Name', 'Age', 'Club', 'Nationality']].head(10).style.background_gradient('copper')
# Out:
# <style  type="text/css" >
# #T_afb47_row0_col1{
#             background-color:  #ffc77f;
#             color:  #000000;
#         }#T_afb47_row1_col1{
#             background-color:  #281910;
#             color:  #f1f1f1;
#         }#T_afb47_row2_col1,#T_afb47_row3_col1,#T_afb47_row4_col1{
#             background-color:  #4f3220;
#             color:  #f1f1f1;
#         }#T_afb47_row5_col1,#T_afb47_row7_col1{
#             background-color:  #ffaf6f;
#             color:  #000000;
#         }#T_afb47_row6_col1{
#             background-color:  #ed9660;
#             color:  #000000;
#         }#T_afb47_row8_col1{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }#T_afb47_row9_col1{
#             background-color:  #9e6440;
#             color:  #000000;
#         }</style><table id="T_afb47_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Name</th>        <th class="col_heading level0 col1" >Age</th>        <th class="col_heading level0 col2" >Club</th>        <th class="col_heading level0 col3" >Nationality</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_afb47_level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_afb47_row0_col0" class="data row0 col0" >Cristiano Ronaldo</td>
#                         <td id="T_afb47_row0_col1" class="data row0 col1" >33</td>
#                         <td id="T_afb47_row0_col2" class="data row0 col2" >Juventus</td>
#                         <td id="T_afb47_row0_col3" class="data row0 col3" >Portugal</td>
#             </tr>
#             <tr>
#                         <th id="T_afb47_level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_afb47_row1_col0" class="data row1 col0" >Neymar Jr</td>
#                         <td id="T_afb47_row1_col1" class="data row1 col1" >26</td>
#                         <td id="T_afb47_row1_col2" class="data row1 col2" >Paris Saint-Germain</td>
#                         <td id="T_afb47_row1_col3" class="data row1 col3" >Brazil</td>
#             </tr>
#             <tr>
#                         <th id="T_afb47_level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_afb47_row2_col0" class="data row2 col0" >De Gea</td>
#                         <td id="T_afb47_row2_col1" class="data row2 col1" >27</td>
#                         <td id="T_afb47_row2_col2" class="data row2 col2" >Manchester United</td>
#                         <td id="T_afb47_row2_col3" class="data row2 col3" >Spain</td>
#             </tr>
#             <tr>
#                         <th id="T_afb47_level0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_afb47_row3_col0" class="data row3 col0" >K. De Bruyne</td>
#                         <td id="T_afb47_row3_col1" class="data row3 col1" >27</td>
#                         <td id="T_afb47_row3_col2" class="data row3 col2" >Manchester City</td>
#                         <td id="T_afb47_row3_col3" class="data row3 col3" >Belgium</td>
#             </tr>
#             <tr>
#                         <th id="T_afb47_level0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_afb47_row4_col0" class="data row4 col0" >E. Hazard</td>
#                         <td id="T_afb47_row4_col1" class="data row4 col1" >27</td>
#                         <td id="T_afb47_row4_col2" class="data row4 col2" >Chelsea</td>
#                         <td id="T_afb47_row4_col3" class="data row4 col3" >Belgium</td>
#             </tr>
#             <tr>
#                         <th id="T_afb47_level0_row5" class="row_heading level0 row5" >6</th>
#                         <td id="T_afb47_row5_col0" class="data row5 col0" >L. Modrić</td>
#                         <td id="T_afb47_row5_col1" class="data row5 col1" >32</td>
#                         <td id="T_afb47_row5_col2" class="data row5 col2" >Real Madrid</td>
#                         <td id="T_afb47_row5_col3" class="data row5 col3" >Croatia</td>
#             </tr>
#             <tr>
#                         <th id="T_afb47_level0_row6" class="row_heading level0 row6" >7</th>
#                         <td id="T_afb47_row6_col0" class="data row6 col0" >L. Suárez</td>
#                         <td id="T_afb47_row6_col1" class="data row6 col1" >31</td>
#                         <td id="T_afb47_row6_col2" class="data row6 col2" >FC Barcelona</td>
#                         <td id="T_afb47_row6_col3" class="data row6 col3" >Uruguay</td>
#             </tr>
#             <tr>
#                         <th id="T_afb47_level0_row7" class="row_heading level0 row7" >8</th>
#                         <td id="T_afb47_row7_col0" class="data row7 col0" >Sergio Ramos</td>
#                         <td id="T_afb47_row7_col1" class="data row7 col1" >32</td>
#                         <td id="T_afb47_row7_col2" class="data row7 col2" >Real Madrid</td>
#                         <td id="T_afb47_row7_col3" class="data row7 col3" >Spain</td>
#             </tr>
#             <tr>
#                         <th id="T_afb47_level0_row8" class="row_heading level0 row8" >9</th>
#                         <td id="T_afb47_row8_col0" class="data row8 col0" >J. Oblak</td>
#                         <td id="T_afb47_row8_col1" class="data row8 col1" >25</td>
#                         <td id="T_afb47_row8_col2" class="data row8 col2" >Atlético Madrid</td>
#                         <td id="T_afb47_row8_col3" class="data row8 col3" >Slovenia</td>
#             </tr>
#             <tr>
#                         <th id="T_afb47_level0_row9" class="row_heading level0 row9" >10</th>
#                         <td id="T_afb47_row9_col0" class="data row9 col0" >R. Lewandowski</td>
#                         <td id="T_afb47_row9_col1" class="data row9 col1" >29</td>
#                         <td id="T_afb47_row9_col2" class="data row9 col2" >FC Bayern München</td>
#                         <td id="T_afb47_row9_col3" class="data row9 col3" >Poland</td>
#             </tr>
#     </tbody></table>

# %%
sns.lmplot(x= 'BallControl', y= 'Dribbling', data=data, col = 'Preferred Foot')
plt.show()

# %%
data.groupby(data['Club'])['Nationality'].nunique().sort_values(ascending= False).head(10)
# Out:
# Club
# No Club                   28
# Brighton & Hove Albion    21
# Fulham                    19
# Udinese                   18
# West Ham United           18
# Empoli                    18
# AS Monaco                 18
# Eintracht Frankfurt       18
# Lazio                     18
# Napoli                    18
# Name: Nationality, dtype: int64

# %%
data.groupby(data['Club'])['Nationality'].nunique().sort_values(ascending=True).head(10)
# Out:
# Club
# Santos                       1
# Ceará Sporting Club          1
# América FC (Minas Gerais)    1
# Paraná                       1
# Chapecoense                  1
# Padova                       1
# Cittadella                   1
# Sangju Sangmu FC             1
# Ranheim Fotball              1
# CA Osasuna                   1
# Name: Nationality, dtype: int64

# %%
def playerdata(x):
    return data.loc[x, :]

pd.set_option('display.max_rows', 200)
x = pd.DataFrame(x)
print(x)
# Out:
#        Age
# 0       31
# 1       33
# 2       26
# 3       27
# 4       27
# ...    ...
# 18202   19
# 18203   19
# 18204   16
# 18205   17
# 18206   16
#
# [18207 rows x 1 columns]
